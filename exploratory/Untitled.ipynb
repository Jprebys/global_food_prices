# %%
import pandas as pd
import numpy as np

# %%
fao = pd.read_csv('../data/FAOSTAT_data_8-28-2020.csv')
wfp = pd.read_csv('../data/wfpvam_foodprices.csv')
# Out:
# C:\Users\jaker\anaconda3\envs\jakerenv\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
fao
# Out:
#        Domain Code           Domain  Area Code      Area  Element Code  \
# 0               PP  Producer Prices          3   Albania          5532
# 1               PP  Producer Prices          3   Albania          5532
# 2               PP  Producer Prices          3   Albania          5532
# 3               PP  Producer Prices          3   Albania          5532
# 4               PP  Producer Prices          3   Albania          5532
# ...            ...              ...        ...       ...           ...
# 148078          PP  Producer Prices        181  Zimbabwe          5532
# 148079          PP  Producer Prices        181  Zimbabwe          5532
# 148080          PP  Producer Prices        181  Zimbabwe          5532
# 148081          PP  Producer Prices        181  Zimbabwe          5532
# 148082          PP  Producer Prices        181  Zimbabwe          5532
#
#                            Element  Item Code                      Item  \
# ...

# %%
wfp.adm0_name.value_counts()
# Out:
# Rwanda                  134075
# Bassas da India         108279
# Syrian Arab Republic     78862
# Mali                     56594
# Kyrgyzstan               54899
#                          ...
# Azerbaijan                 125
# Eritrea                    100
# Georgia                     80
# Venezuela                    6
# Italy                        1
# Name: adm0_name, Length: 99, dtype: int64

# %%
wfp[wfp.adm0_name == 'Rwanda']
# Out:
#          adm0_id adm0_name  adm1_id                     adm1_name  mkt_id  \
# 1052940    205.0    Rwanda     2587  Kigali City/Umujyi wa Kigali    1054
# 1052941    205.0    Rwanda     2587  Kigali City/Umujyi wa Kigali    1054
# 1052942    205.0    Rwanda     2587  Kigali City/Umujyi wa Kigali    1054
# 1052943    205.0    Rwanda     2587  Kigali City/Umujyi wa Kigali    1054
# 1052944    205.0    Rwanda     2587  Kigali City/Umujyi wa Kigali    1054
# ...          ...       ...      ...                           ...     ...
# 1187010    205.0    Rwanda    21973           West/Iburengerazuba    2379
# 1187011    205.0    Rwanda    21973           West/Iburengerazuba    2379
# 1187012    205.0    Rwanda    21973           West/Iburengerazuba    2379
# 1187013    205.0    Rwanda    21973           West/Iburengerazuba    2379
# 1187014    205.0    Rwanda    21973           West/Iburengerazuba    2379
#
#          mkt_name  cm_id                  cm_name  cur_id cur_name  pt_id  \
# ...

# %%
food_avgs = wfp.groupby(['cm_name', 'mp_year'])['mp_price'].mean().unstack()

# %%
food_avgs.describe()
# Out:
# mp_year        1990        1991        1992        1993        1994  \
# count      3.000000    3.000000    4.000000    4.000000   10.000000
# mean     108.648870  110.986408   83.327626   81.113417   70.184455
# std       80.395104   67.566057   81.709494   83.226532   82.372694
# min       58.695652   69.988636    1.527500    1.555000    1.322667
# 25%       62.278861   71.994318   46.827188   44.567321    9.450700
# 50%       65.862069   74.000000   67.697057   62.324334   51.549668
# 75%      133.625479  131.485294  104.197496   98.870430   73.387636
# max      201.388889  188.970588  196.388889  198.250000  255.763889
#
# mp_year         1995         1996           1997           1998  \
# count      12.000000    16.000000      17.000000      21.000000
# mean      194.786743   304.387529   43049.442326   33828.693594
# std       364.319453   526.061464  144777.649348  130079.939218
# min         1.332500     1.688333       1.773333       1.110000
# ...

# %%
food_avgs
# Out:
# mp_year                   1990  1991  1992  1993  1994  1995  1996  1997  \
# cm_name
# Apples (dried) - Retail    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Apples (red) - Retail      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Apples (red) - Wholesale   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Apples - Retail            NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Apples - Wholesale         NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...                        ...   ...   ...   ...   ...   ...   ...   ...
# Yam - Retail               NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Yam - Wholesale            NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Yeast - Retail             NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Yogurt - Retail            NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Zucchini - Retail          NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# mp_year                   1998  1999  ...        2011         2012  \
# ...
